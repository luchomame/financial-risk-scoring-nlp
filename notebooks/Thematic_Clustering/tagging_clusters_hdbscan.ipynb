# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
import ast

# %% [markdown]
# **For HDBSCAN I only saved the cluster IDs not the vectors**

# %%
import os 
from dotenv import load_dotenv
from pathlib import Path
load_dotenv()
CSV_OUTPUT_PATH = Path(os.getenv("CSV_OUTPUT_PATH"))
CSV_FILE = os.getenv("CLEANED_ARTICLES_FILENAME")

MODEL_OUTPUT_PATH = Path(os.getenv("MODEL_OUTPUT_PATH"))
NP_OUTPUT_PATH = Path(os.getenv("NP_OUTPUT_PATH"))
MODEL_FILE = os.getenv("MODEL_FILENAME")
EMBEDDED_ARTICLES_FILENAME = os.getenv("EMBEDDED_ARTICLES_FILENAME")


CLEANED_ARTICLES_FILENAME=os.getenv("CLEANED_ARTICLES_FILENAME")
EMBEDDED_ARTICLES_FILENAME=os.getenv("EMBEDDED_ARTICLES_FILENAME")
MODEL_FILENAME=os.getenv("MODEL_FILENAME")
GROUPED_RISK_TAGS_CSV=os.getenv("GROUPED_RISK_TAGS_CSV")
ARTICLES_WITH_RISK_TAGS_CSV=os.getenv("ARTICLES_WITH_RISK_TAGS_CSV")
LM_LEXICON_FILENAME=os.getenv("LM_LEXICON_FILENAME")
STOCK_RISK_EXPOSURE_CSV=os.getenv("STOCK_RISK_EXPOSURE_CSV")
HDBSCAN_SUBCLUSTER_LABELS=os.getenv("HDBSCAN_SUBCLUSTER_LABELS")
HDBSCAN_RISK_TAGS=os.getenv("HDBSCAN_RISK_TAGS")
HDBSCAN_GROUPED_RISK_TAGS=os.getenv("HDBSCAN_GROUPED_RISK_TAGS")

# %%
# Load saved clusters
data_with_clusters = np.load(f"{NP_OUTPUT_PATH}/{HDBSCAN_SUBCLUSTER_LABELS}")
# article_vectors = data_with_clusters[:, :-1]  # Extract article vectors
cluster_labels = data_with_clusters  # Extract cluster labels

# Count articles in each cluster
cluster_counts = pd.Series(cluster_labels).value_counts().sort_index()

# Print cluster sizes
print("Cluster Distribution:\n", cluster_counts)

# Plot cluster sizes
plt.figure(figsize=(12, 5))
cluster_counts.plot(kind="bar", color="steelblue")
plt.xlabel("Cluster ID")
plt.ylabel("Number of Articles")
plt.title("HDBSCAN Cluster Distribution")
plt.xticks(rotation=45)
plt.show()
# Out:
# Cluster Distribution:
#  -1.0      86098
#  0.0        187
#  2.0        102
#  10.0      1047
#  11.0       489
#  12.0       482
#  13.0    168050
#  14.0      1651
#  15.0      1035
# Name: count, dtype: int64

# %%
# Load cleaned dataset 
df_cleaned = pd.read_csv(f"{CSV_OUTPUT_PATH}/{CLEANED_ARTICLES_FILENAME}")
# remove dupes from title 
df_cleaned = df_cleaned.drop_duplicates(subset=['article_title'])

# %%
# Convert token strings back to lists (if stored as strings)
df_cleaned["tokens"] = df_cleaned["tokens"].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Add DBSCAN cluster labels to dataset
df_cleaned["cluster"] = cluster_labels.astype(int)  # Ensure int type for easier grouping

# Function to get most common words per cluster
def get_top_words(cluster_id, n=15):
    words = [word for tokens in df_cleaned[df_cleaned["cluster"] == cluster_id]["tokens"] for word in tokens]
    word_counts = Counter(words).most_common(n)
    return word_counts

# Analyze a few sample clusters
sample_clusters = [0, 10, 2, 13, 14]  # Adjust based on distribution
for cluster_id in sample_clusters:
    print(f"\n**Top Words in Cluster {cluster_id}:**")
    print(get_top_words(cluster_id))
# Out:
# **Top Words in Cluster 0:**
# [('day', 378), ('zack', 374), ('bull', 374), ('bear', 374), ('highlight', 299), ('article', 75), ('technology', 24), ('holding', 18), ('healthcare', 12), ('global', 12), ('energy', 12), ('industry', 12), ('vertiv', 10), (' ', 10), ('service', 10)]
#
# **Top Words in Cluster 1:**
# []
#
# **Top Words in Cluster 2:**
# [('fund', 102), ('manager', 102), ('li', 102), ('lu', 102), ('charlie', 102), ('munger', 102), ('back', 102), ('say', 102), ('debt', 66), ('investment', 56), ('risk', 55), ('make', 54), ('external', 53), ('berkshire', 53), ('hathaways', 53)]
#
# **Top Words in Cluster 3:**
# []
#
# **Top Words in Cluster 4:**
# []

# %%
df_cleaned[df_cleaned["cluster"] == 0]
# Out:
#        ticker mapped_trading_date  \
# 91        DVN          2024-11-22
# 386      FANG          2024-09-10
# 2306     LSTR          2024-08-07
# 3067     MRVL          2025-01-09
# 4769     SBUX          2024-11-06
# ...       ...                 ...
# 342208   GTLB          2024-10-25
# 347270    VST          2024-12-24
# 350887   RIVN          2024-06-27
# 357943    BAC          2024-06-18
# 359248   CSCO          2024-02-12
#
#                                             article_title  \
# 91      Tesla and Hershey have been highlighted as Zac...
# 386     Illumina and Exxon Mobile have been highlighte...
# 2306    Datadog and Landstar System have been highligh...
# 3067    Marvell Technology and Hooker Furniture in the...
# 4769    Tenet Healthcare and Starbucks have been highl...
# ...                                                   ...
# 342208  GitLab and Baidu have been highlighted as Zack...
# 347270  Vistra and Vera Bradley have been highlighted ...
# 350887  BRC and American Woodmark have been highlighte...
# 357943  Sunoco and Adient's have been highlighted as Z...
# 359248  H&R Block and Douglas Dynamics have been highl...
#
#                                               description  \
# 91      Tesla and Hershey have been highlighted as Zac...
# 386     Illumina and Exxon Mobile have been highlighte...
# 2306    Datadog and Landstar System have been highligh...
# 3067    Marvell Technology and Hooker Furniture in the...
# 4769    Tenet Healthcare and Starbucks are part of the...
# ...                                                   ...
# 342208  GitLab and Baidu have been highlighted as Zack...
# 347270  Vistra and Vera Bradley are part of the Zacks ...
# 350887  BRC and American Woodmark have been highlighte...
# 357943  Sunoco and Adient's are part of the Zacks Bull...
# 359248  H&R Block and Douglas Dynamics have been highl...
#
#                                                 full_text  \
# 91      Tesla and Hershey have been highlighted as Zac...
# 386     Illumina and Exxon Mobile have been highlighte...
# 2306    Datadog and Landstar System have been highligh...
# 3067    Marvell Technology and Hooker Furniture in the...
# 4769    Tenet Healthcare and Starbucks have been highl...
# ...                                                   ...
# 342208  GitLab and Baidu have been highlighted as Zack...
# 347270  Vistra and Vera Bradley have been highlighted ...
# 350887  BRC and American Woodmark have been highlighte...
# 357943  Sunoco and Adient's have been highlighted as Z...
# 359248  H&R Block and Douglas Dynamics have been highl...
#
#                                                clean_text  \
# 91      tesla and hershey have been highlighted as zac...
# 386     illumina and exxon mobile have been highlighte...
# 2306    datadog and landstar system have been highligh...
# 3067    marvell technology and hooker furniture in the...
# 4769    tenet healthcare and starbucks have been highl...
# ...                                                   ...
# 342208  gitlab and baidu have been highlighted as zack...
# 347270  vistra and vera bradley have been highlighted ...
# 350887  brc and american woodmark have been highlighte...
# 357943  sunoco and adients have been highlighted as za...
# 359248  hr block and douglas dynamics have been highli...
#
#                                                    tokens  cluster
# 91      [tesla, hershey, highlight, zack, bull, bear, ...        0
# 386     [illumina, exxon, mobile, highlight, zack, bul...        0
# 2306    [datadog, landstar, system, highlight, zack, b...        0
# 3067    [marvell, technology, hooker, furniture, box, ...        0
# 4769    [tenet, healthcare, starbuck, highlight, zack,...        0
# ...                                                   ...      ...
# 342208  [gitlab, baidu, highlight, zack, bull, bear, d...        0
# 347270  [vistra, vera, bradley, highlight, zack, bull,...        0
# 350887  [brc, american, woodmark, highlight, zack, bul...        0
# 357943  [sunoco, adient, highlight, zack, bull, bear, ...        0
# 359248  [hr, block, douglas, dynamic, highlight, zack,...        0
#
# [187 rows x 8 columns]

# %%
# Load Loughran-McDonald Lexicon
lm_df = pd.read_csv(f"{CSV_OUTPUT_PATH}/{LM_LEXICON_FILENAME}")

# Define sentiment categories
sentiment_categories = ['Negative', 'Positive', 'Uncertainty', 'Litigious', 'Strong_Modal', 'Weak_Modal']
lm_sentiment_dict = {category: set(lm_df[lm_df[category] > 0]['Word'].str.lower()) for category in sentiment_categories}

# %%
lm_sentiment_dict["Uncertainty"]
# Out:
# {'abeyance',
#  'abeyances',
#  'almost',
#  'alteration',
#  'alterations',
#  'ambiguities',
#  'ambiguity',
#  'ambiguous',
#  'anomalies',
#  'anomalous',
#  'anomalously',
#  'anomaly',
#  'anticipate',
#  'anticipated',
#  'anticipates',
#  'anticipating',
#  'anticipation',
#  'anticipations',
#  'apparent',
#  'apparently',
#  'appear',
#  'appeared',
#  'appearing',
#  'appears',
#  'approximate',
#  'approximated',
#  'approximately',
#  'approximates',
#  'approximating',
#  'approximation',
#  'approximations',
#  'arbitrarily',
#  'arbitrariness',
#  'arbitrary',
#  'assume',
#  'assumed',
#  'assumes',
#  'assuming',
#  'assumption',
#  'assumptions',
#  'believe',
#  'believed',
#  'believes',
#  'believing',
#  'cautious',
#  'cautiously',
#  'cautiousness',
#  'clarification',
#  'clarifications',
#  'conceivable',
#  'conceivably',
#  'conditional',
#  'conditionally',
#  'confuses',
#  'confusing',
#  'confusingly',
#  'confusion',
#  'contingencies',
#  'contingency',
#  'contingent',
#  'contingently',
#  'contingents',
#  'could',
#  'crossroad',
#  'crossroads',
#  'depend',
#  'depended',
#  'dependence',
#  'dependencies',
#  'dependency',
#  'dependent',
#  'depending',
#  'depends',
#  'destabilizing',
#  'deviate',
#  'deviated',
#  'deviates',
#  'deviating',
#  'deviation',
#  'deviations',
#  'differ',
#  'differed',
#  'differing',
#  'differs',
#  'doubt',
#  'doubted',
#  'doubtful',
#  'doubts',
#  'exposure',
#  'exposures',
#  'fluctuate',
#  'fluctuated',
#  'fluctuates',
#  'fluctuating',
#  'fluctuation',
#  'fluctuations',
#  'hidden',
#  'hinges',
#  'imprecise',
#  'imprecision',
#  'imprecisions',
#  'improbability',
#  'improbable',
#  'incompleteness',
#  'indefinite',
#  'indefinitely',
#  'indefiniteness',
#  'indeterminable',
#  'indeterminate',
#  'inexact',
#  'inexactness',
#  'instabilities',
#  'instability',
#  'intangible',
#  'intangibles',
#  'likelihood',
#  'may',
#  'maybe',
#  'might',
#  'nearly',
#  'nonassessable',
#  'occasionally',
#  'ordinarily',
#  'pending',
#  'perhaps',
#  'possibilities',
#  'possibility',
#  'possible',
#  'possibly',
#  'precaution',
#  'precautionary',
#  'precautions',
#  'predict',
#  'predictability',
#  'predicted',
#  'predicting',
#  'prediction',
#  'predictions',
#  'predictive',
#  'predictor',
#  'predictors',
#  'predicts',
#  'preliminarily',
#  'preliminary',
#  'presumably',
#  'presume',
#  'presumed',
#  'presumes',
#  'presuming',
#  'presumption',
#  'presumptions',
#  'probabilistic',
#  'probabilities',
#  'probability',
#  'probable',
#  'probably',
#  'random',
#  'randomize',
#  'randomized',
#  'randomizes',
#  'randomizing',
#  'randomly',
#  'randomness',
#  'reassess',
#  'reassessed',
#  'reassesses',
#  'reassessing',
#  'reassessment',
#  'reassessments',
#  'recalculate',
#  'recalculated',
#  'recalculates',
#  'recalculating',
#  'recalculation',
#  'recalculations',
#  'reconsider',
#  'reconsidered',
#  'reconsidering',
#  'reconsiders',
#  'reexamination',
#  'reexamine',
#  'reexamining',
#  'reinterpret',
#  'reinterpretation',
#  'reinterpretations',
#  'reinterpreted',
#  'reinterpreting',
#  'reinterprets',
#  'revise',
#  'revised',
#  'risk',
#  'risked',
#  'riskier',
#  'riskiest',
#  'riskiness',
#  'risking',
#  'risks',
#  'risky',
#  'roughly',
#  'rumors',
#  'seems',
#  'seldom',
#  'seldomly',
#  'sometime',
#  'sometimes',
#  'somewhat',
#  'somewhere',
#  'speculate',
#  'speculated',
#  'speculates',
#  'speculating',
#  'speculation',
#  'speculations',
#  'speculative',
#  'speculatively',
#  'sporadic',
#  'sporadically',
#  'sudden',
#  'suddenly',
#  'suggest',
#  'suggested',
#  'suggesting',
#  'suggests',
#  'susceptibility',
#  'tending',
#  'tentative',
#  'tentatively',
#  'turbulence',
#  'uncertain',
#  'uncertainly',
#  'uncertainties',
#  'uncertainty',
#  'unclear',
#  'unconfirmed',
#  'undecided',
#  'undefined',
#  'undesignated',
#  'undetectable',
#  'undeterminable',
#  'undetermined',
#  'undocumented',
#  'unexpected',
#  'unexpectedly',
#  'unfamiliar',
#  'unfamiliarity',
#  'unforecasted',
#  'unforseen',
#  'unguaranteed',
#  'unhedged',
#  'unidentifiable',
#  'unidentified',
#  'unknown',
#  'unknowns',
#  'unobservable',
#  'unplanned',
#  'unpredictability',
#  'unpredictable',
#  'unpredictably',
#  'unpredicted',
#  'unproved',
#  'unproven',
#  'unquantifiable',
#  'unquantified',
#  'unreconciled',
#  'unseasonable',
#  'unseasonably',
#  'unsettled',
#  'unspecific',
#  'unspecified',
#  'untested',
#  'unusual',
#  'unusually',
#  'unwritten',
#  'vagaries',
#  'vague',
#  'vaguely',
#  'vagueness',
#  'vaguenesses',
#  'vaguer',
#  'vaguest',
#  'variability',
#  'variable',
#  'variables',
#  'variably',
#  'variance',
#  'variances',
#  'variant',
#  'variants',
#  'variation',
#  'variations',
#  'varied',
#  'varies',
#  'vary',
#  'varying',
#  'volatile',
#  'volatilities',
#  'volatility'}

# %%
def assign_risk_theme(cluster_id):
    words = [word for tokens in df_cleaned[df_cleaned["cluster"] == cluster_id]["tokens"] for word in tokens]
    word_counts = Counter(words)
    total_words = sum(word_counts.values())

    category_proportions = {}
    for category, word_set in lm_sentiment_dict.items():
        category_count = sum(count for word, count in word_counts.items() if word in word_set)
        category_proportions[category] = category_count / total_words if total_words > 0 else 0

    # Custom thresholds
    low_freq_categories = ['Litigious', 'Strong_Modal', 'Weak_Modal','Uncertainty']
    threshold = {cat: 0.01 if cat in low_freq_categories else 0.05 for cat in category_proportions}

    # Apply threshold check
    valid_categories = {cat: score for cat, score in category_proportions.items() if score > threshold[cat]}

    if valid_categories:
        dominant_category = max(valid_categories, key=valid_categories.get)
        return dominant_category
    else:
        return 'Mixed Sentiment'

# %%
# Function to assign a risk theme to a cluster
# def assign_risk_theme(cluster_id):
#     words = [word for tokens in df_cleaned[df_cleaned["cluster"] == cluster_id]["tokens"] for word in tokens]
#     word_counts = Counter(words)
#     total_words = sum(word_counts.values())

#     category_proportions = {}
#     for category, word_set in lm_sentiment_dict.items():
#         category_count = sum(count for word, count in word_counts.items() if word in word_set)
#         category_proportions[category] = category_count / total_words if total_words > 0 else 0

#     # Determine dominant category
#     dominant_category = max(category_proportions, key=category_proportions.get)
#     return dominant_category if category_proportions[dominant_category] > 0.01 else 'Mixed Sentiment'


# Assign risk labels to all clusters
# cluster_risk_labels = {cluster_id: assign_risk_theme(cluster_id) for cluster_id in cluster_counts.index}
filtered_clusters = [c for c in cluster_counts.index if c != 0]
cluster_risk_labels = {cluster_id: assign_risk_theme(cluster_id) for cluster_id in filtered_clusters}

# Print risk labels
print("\n**Cluster Risk Labels:**")
for cluster_id, risk_theme in cluster_risk_labels.items():
    print(f"Cluster {cluster_id}: {risk_theme}")
# Out:
# **Cluster Risk Labels:**
# Cluster -1.0: Mixed Sentiment
# Cluster 2.0: Uncertainty
# Cluster 10.0: Mixed Sentiment
# Cluster 11.0: Mixed Sentiment
# Cluster 12.0: Uncertainty
# Cluster 13.0: Mixed Sentiment
# Cluster 14.0: Mixed Sentiment
# Cluster 15.0: Uncertainty

# %%
# Function to get top words per cluster
def get_top_words(cluster_id, n=20):
    words = [word for tokens in df_cleaned[df_cleaned["cluster"] == cluster_id]["tokens"] for word in tokens]
    word_counts = Counter(words).most_common(n)
    return word_counts

# Check high-risk clusters
high_risk_clusters = [12, 14]  # Uncertainty and Negative clusters
for cluster_id in high_risk_clusters:
    print(f"\n**Top Words in Cluster {cluster_id}:**")
    print(get_top_words(cluster_id))
# Out:
# **Top Words in Cluster 12:**
# [('option', 964), ('stock', 964), ('market', 618), ('need', 482), ('pay', 482), ('close', 482), ('attention', 482), ('base', 482), ('movement', 482), ('lately', 482), ('investor', 481), ('trader', 227), ('know', 141), ('not', 141), ('predict', 136), ('spike', 136), ('imply', 119), ('volatility', 119), ('surge', 119), ('bet', 86)]
#
# **Top Words in Cluster 14:**
# [('value', 2713), ('fair', 1954), ('insight', 1656), ('key', 1651), ('2', 1636), ('stage', 1636), ('free', 1636), ('cash', 1636), ('flow', 1635), ('equity', 1597), ('estimate', 1522), ('base', 1177), ('%', 958), ('share', 945), ('intrinsic', 905), ('inc', 901), ('project', 563), ('current', 483), ('price', 445), ('corporation', 361)]

# %%
# Count how many articles per stock belong to each risk cluster
stock_risk_exposure = df_cleaned.groupby(["ticker", "cluster"]).size().unstack(fill_value=0)

# Merge risk labels
stock_risk_exposure.columns = [cluster_risk_labels.get(cluster_id, "Unknown") for cluster_id in stock_risk_exposure.columns]

# Save results
# stock_risk_exposure.to_csv("scratch/Word2Vec/stock_risk_exposure.csv")

# Show a sample
print("\n**Stock-Level Risk Exposure:**")
print(stock_risk_exposure.head(20))
# Out:
# **Stock-Level Risk Exposure:**
#         Mixed Sentiment  Unknown  Uncertainty  Mixed Sentiment  \
# ticker
# A                    57        0            0                2
# AA                   19        0            0                0
# AAL                 130        0            0                0
# AAON                 13        0            0                0
# AAP                  36        0            0                0
# AAPL               1121        0            0                0
# ABBV                226        0            0                1
# ABCB                 13        0            0                0
# ABG                  32        0            0                0
# ABNB                214        0            1                4
# ABT                 167        0            0                3
# ACA                  21        0            0                0
# ACAD                  8        0            0                0
# ACGL                 55        0            0                2
# ACHC                 27        0            0                0
# ACI                 136        0            0                1
# ACIW                 19        0            0                0
# ACLS                 20        0            0                0
# ACLX                 10        0            0                0
# ACM                  48        0            0                6
#
#         Mixed Sentiment  Uncertainty  Mixed Sentiment  Mixed Sentiment  \
# ticker
# A                     0            2              155                5
# AA                    1            1               72                0
# AAL                   0            2              211                1
# AAON                  0            3               64                2
# AAP                   0            1               43                1
# AAPL                  4            1             2514                2
# ABBV                  4            1              439                0
# ABCB                  0            1               31                0
# ABG                   0            0               47                1
# ABNB                  4            3              407                6
# ABT                   0            1              232                4
# ACA                   0            2               57                2
# ACAD                  0            1               38                0
# ACGL                  0            5               94                0
# ACHC                  0            2               40                0
# ACI                   0            3              150                1
# ACIW                  0            2               58                1
# ACLS                  3            2               68                1
# ACLX                  0            0               28                2
# ACM                   0            2               90                1
#
#         Uncertainty
# ticker
# A                 0
# AA                0
# AAL               0
# AAON              0
# AAP               0
# AAPL              3
# ABBV              5
# ABCB              0
# ABG               0
# ABNB              0
# ABT               7
# ACA               1
# ACAD              0
# ACGL              5
# ACHC              0
# ACI               0
# ACIW              0
# ACLS              4
# ACLX              0
# ACM               0

# %% [markdown]
# # Multi Tagging

# %%
# Define thresholds for each category
low_freq_categories = ['Uncertainty', 'Litigious', 'Strong_Modal', 'Weak_Modal']
category_thresholds = {cat: 0.01 if cat in low_freq_categories else 0.01 for cat in sentiment_categories}

# %%
from collections import Counter

def assign_risk_themes_multi(cluster_id):
    words = [word for tokens in df_cleaned[df_cleaned["cluster"] == cluster_id]["tokens"] for word in tokens]
    word_counts = Counter(words)
    total_words = sum(word_counts.values())

    category_proportions = {}
    for category, word_set in lm_sentiment_dict.items():
        category_count = sum(count for word, count in word_counts.items() if word in word_set)
        category_proportions[category] = category_count / total_words if total_words > 0 else 0

    # Select all categories that pass their respective thresholds
    selected_categories = [
        cat for cat, prop in category_proportions.items()
        if prop > category_thresholds.get(cat, 0.05)
    ]

    return selected_categories if selected_categories else ['Mixed Sentiment']

# %%
cluster_risk_labels_multi = {
    cluster_id: assign_risk_themes_multi(cluster_id)
    for cluster_id in cluster_counts.index
}

# Print the results
print("\n**Multi-Label Cluster Risk Tags:**")
for cluster_id, risk_tags in cluster_risk_labels_multi.items():
    print(f"Cluster {cluster_id}: {risk_tags}")
# Out:
# **Multi-Label Cluster Risk Tags:**
# Cluster -1.0: ['Negative', 'Positive']
# Cluster 0.0: ['Mixed Sentiment']
# Cluster 2.0: ['Negative', 'Uncertainty']
# Cluster 10.0: ['Mixed Sentiment']
# Cluster 11.0: ['Mixed Sentiment']
# Cluster 12.0: ['Negative', 'Uncertainty']
# Cluster 13.0: ['Negative', 'Positive']
# Cluster 14.0: ['Mixed Sentiment']
# Cluster 15.0: ['Negative', 'Positive', 'Uncertainty']

# %%
df_cleaned["risk_tags"] = df_cleaned["cluster"].map(cluster_risk_labels_multi)
df_exploded = df_cleaned.explode("risk_tags")

print(df_exploded["risk_tags"].value_counts())
df_exploded.head(10)
# Out:
# risk_tags
# Negative           255767
# Positive           255183
# Mixed Sentiment      3374
# Uncertainty          1619
# Name: count, dtype: int64
#   ticker mapped_trading_date  \
# 0    DXC          2024-07-11
# 0    DXC          2024-07-11
# 1    DRI          2024-07-17
# 1    DRI          2024-07-17
# 2    DVA          2024-07-19
# 2    DVA          2024-07-19
# 3    DRI          2024-07-22
# 3    DRI          2024-07-22
# 4    DVA          2024-07-23
# 4    DVA          2024-07-23
#
#                                        article_title  \
# 0  DXC Technology to Report Fiscal First Quarter ...
# 0  DXC Technology to Report Fiscal First Quarter ...
# 1         Darden to buy Chuyâs for more than $600M
# 1         Darden to buy Chuyâs for more than $600M
# 2  Update: DaVita to Pay $34.5 Million for Settle...
# 2  Update: DaVita to Pay $34.5 Million for Settle...
# 3  Analysts Have Made A Financial Statement On Da...
# 3  Analysts Have Made A Financial Statement On Da...
# 4  DaVita HealthCare (DVA) Laps the Stock Market:...
# 4  DaVita HealthCare (DVA) Laps the Stock Market:...
#
#                                          description  \
# 0  ASHBURN, Va., July 10, 2024--DXC Technology (N...
# 0  ASHBURN, Va., July 10, 2024--DXC Technology (N...
# 1  The all-cash transaction will add a Tex-Mex ch...
# 1  The all-cash transaction will add a Tex-Mex ch...
# 2  Update: DaVita to Pay $34.5 Million for Settle...
# 2  Update: DaVita to Pay $34.5 Million for Settle...
# 3  Last week saw the newest yearly earnings relea...
# 3  Last week saw the newest yearly earnings relea...
# 4  The latest trading day saw DaVita HealthCare (...
# 4  The latest trading day saw DaVita HealthCare (...
#
#                                            full_text  \
# 0  DXC Technology to Report Fiscal First Quarter ...
# 0  DXC Technology to Report Fiscal First Quarter ...
# 1  Darden to buy Chuyâs for more than $600M The...
# 1  Darden to buy Chuyâs for more than $600M The...
# 2  Update: DaVita to Pay $34.5 Million for Settle...
# 2  Update: DaVita to Pay $34.5 Million for Settle...
# 3  Analysts Have Made A Financial Statement On Da...
# 3  Analysts Have Made A Financial Statement On Da...
# 4  DaVita HealthCare (DVA) Laps the Stock Market:...
# 4  DaVita HealthCare (DVA) Laps the Stock Market:...
#
#                                           clean_text  \
# 0  dxc technology to report fiscal first quarter ...
# 0  dxc technology to report fiscal first quarter ...
# 1  darden to buy chuyâs for more than $600m the a...
# 1  darden to buy chuyâs for more than $600m the a...
# 2  update davita to pay $345 million for settleme...
# 2  update davita to pay $345 million for settleme...
# 3  analysts have made a financial statement on da...
# 3  analysts have made a financial statement on da...
# 4  davita healthcare dva laps the stock market he...
# 4  davita healthcare dva laps the stock market he...
#
#                                               tokens  cluster risk_tags
# 0  [dxc, technology, report, fiscal, quarter, 202...       13  Negative
# 0  [dxc, technology, report, fiscal, quarter, 202...       13  Positive
# 1  [darden, buy, chuyâs, $, 600, m, allcash, tran...       -1  Negative
# 1  [darden, buy, chuyâs, $, 600, m, allcash, tran...       -1  Positive
# 2  [update, davita, pay, $, 345, million, settlem...       -1  Negative
# 2  [update, davita, pay, $, 345, million, settlem...       -1  Positive
# 3  [analyst, financial, statement, darden, restau...       -1  Negative
# 3  [analyst, financial, statement, darden, restau...       -1  Positive
# 4  [davita, healthcare, dva, lap, stock, market, ...       13  Negative
# 4  [davita, healthcare, dva, lap, stock, market, ...       13  Positive

# %%
stock_risk_exposure = (
    df_exploded
    .groupby(["article_title", "risk_tags"])
    .size()
    .unstack(fill_value=0)
    .sort_index(axis=1)  
)

stock_risk_exposure.head(10)
# Out:
# risk_tags                                           Mixed Sentiment  Negative  \
# article_title
# "Bad News" is Good News for these 3 Stocks                        0         1
# "Barneyâs World" to Premiere Monday, October ...                0         1
# "Big 3" carmakers face "tough choices" to hit i...                0         1
# "Big Short" Investor Michael Burry Has 10% of H...                0         1
# "Communications for Good" Provides Maximus Foun...                0         1
# "Decoded": Groundbreaking Chinese Psychological...                0         1
# "EXPERIENCE MORE AT SEAâ¢" WITH NORWEGIAN CRUI...                0         1
# "Empowering American Cities" Initiative Reveals...                0         1
# "FAN FIRST" PROGRAM BEST PLACE FOR KNICKS AND R...                0         1
# "Finish Your Story" in WWEÂ® 2K24 Deluxe Editio...                0         1
#
# risk_tags                                           Positive  Uncertainty
# article_title
# "Bad News" is Good News for these 3 Stocks                 1            0
# "Barneyâs World" to Premiere Monday, October ...         1            0
# "Big 3" carmakers face "tough choices" to hit i...         1            0
# "Big Short" Investor Michael Burry Has 10% of H...         1            0
# "Communications for Good" Provides Maximus Foun...         1            0
# "Decoded": Groundbreaking Chinese Psychological...         1            0
# "EXPERIENCE MORE AT SEAâ¢" WITH NORWEGIAN CRUI...         1            0
# "Empowering American Cities" Initiative Reveals...         1            0
# "FAN FIRST" PROGRAM BEST PLACE FOR KNICKS AND R...         1            0
# "Finish Your Story" in WWEÂ® 2K24 Deluxe Editio...         1            0

# %%
# # normalize...maybe not needed?
# stock_risk_percent = stock_risk_exposure.div(stock_risk_exposure.sum(axis=1), axis=0)
# stock_risk_percent

# %%
df_cleaned.columns
# Out:
# Index(['ticker', 'mapped_trading_date', 'article_title', 'description',
#        'full_text', 'clean_text', 'tokens', 'cluster', 'risk_tags'],
#       dtype='object')

# %% [markdown]
# # Join with Original

# %%
df_original = pd.read_csv(f"{CSV_OUTPUT_PATH}/{CLEANED_ARTICLES_FILENAME}")

# %%
df_risk = df_original.merge(
    stock_risk_exposure,
    how="left",
    left_on="article_title",
    right_index=True
)

# %%
print(df_risk.columns)
df_risk.tail(10)#[['article_title', 'ticker', 'Negative', 'Positive', 'Uncertainty']])
# Out:
# Index(['ticker', 'mapped_trading_date', 'article_title', 'description',
#        'full_text', 'clean_text', 'tokens', 'Mixed Sentiment', 'Negative',
#        'Positive', 'Uncertainty'],
#       dtype='object')
#        ticker mapped_trading_date  \
# 363810    MRK          2024-07-15
# 363811    MOH          2024-07-17
# 363812    MRK          2024-07-18
# 363813     MO          2024-07-24
# 363814    MOD          2024-07-29
# 363815   MORN          2024-07-30
# 363816    MOD          2024-07-31
# 363817     MO          2024-08-01
# 363818   MPWR          2024-08-02
# 363819    MOH          2024-08-15
#
#                                             article_title  \
# 363810  The Zacks Analyst Blog Highlights Exxon  Mobil...
# 363811  Would Trump Ease Up on Medicare? Wall Street T...
# 363812  Insiders At Merck Sold US$12m In Stock, Alludi...
# 363813  Investors Heavily Search Altria Group, Inc. (M...
# 363814  Is Modine (MOD) a Solid Growth Stock? 3 Reason...
# 363815  Morningstar Retirement Launches New Morningsta...
# 363816   Modine Reports First Quarter Fiscal 2025 Results
# 363817                       Company News for Aug 1, 2024
# 363818  Monolithic Power (MPWR) Beats Q2 Earnings and ...
# 363819  Michael Burry's Strategic Emphasis on Shift4 P...
#
#                                               description  \
# 363810  are included in this Analyst Blog Exxon Mobil,...
# 363811  Investors bet that if Donald Trump is elected ...
# 363812  Over the past year, many Merck & Co., Inc. ( N...
# 363813  Zacks.com users have recently been watching Al...
# 363814  Modine (MOD) possesses solid growth attributes...
# 363815  CHICAGO, July 30, 2024--Morningstar Retirement...
# 363816  Modine (NYSE: MOD), a diversified global leade...
# 363817       Companies in The News Are: AMD, ANET, MA, MO
# 363818  Monolithic (MPWR) delivered earnings and reven...
# 363819  Insight into the Latest 13F Filing and Key Por...
#
#                                                 full_text  \
# 363810  The Zacks Analyst Blog Highlights Exxon  Mobil...
# 363811  Would Trump Ease Up on Medicare? Wall Street T...
# 363812  Insiders At Merck Sold US$12m In Stock, Alludi...
# 363813  Investors Heavily Search Altria Group, Inc. (M...
# 363814  Is Modine (MOD) a Solid Growth Stock? 3 Reason...
# 363815  Morningstar Retirement Launches New Morningsta...
# 363816  Modine Reports First Quarter Fiscal 2025 Resul...
# 363817  Company News for Aug 1, 2024 Companies in The ...
# 363818  Monolithic Power (MPWR) Beats Q2 Earnings and ...
# 363819  Michael Burry's Strategic Emphasis on Shift4 P...
#
#                                                clean_text  \
# 363810  the zacks analyst blog highlights exxon mobil ...
# 363811  would trump ease up on medicare wall street th...
# 363812  insiders at merck sold us$12m in stock alludin...
# 363813  investors heavily search altria group inc mo h...
# 363814  is modine mod a solid growth stock 3 reasons t...
# 363815  morningstar retirement launches new morningsta...
# 363816  modine reports first quarter fiscal 2025 resul...
# 363817  company news for aug 1 2024 companies in the n...
# 363818  monolithic power mpwr beats q2 earnings and re...
# 363819  michael burrys strategic emphasis on shift4 pa...
#
#                                                    tokens  Mixed Sentiment  \
# 363810  ['zack', 'analyst', 'blog', 'highlight', 'exxo...                0
# 363811  ['trump', 'ease', 'medicare', 'wall', 'street'...                0
# 363812  ['insider', 'merck', 'sell', 'us$12', 'm', 'st...                0
# 363813  ['investor', 'heavily', 'search', 'altria', 'g...                1
# 363814  ['modine', 'mod', 'solid', 'growth', 'stock', ...                0
# 363815  ['morningstar', 'retirement', 'launch', 'new',...                0
# 363816  ['modine', 'report', 'quarter', 'fiscal', '202...                0
# 363817  ['company', 'news', 'aug', '1', '2024', 'compa...                0
# 363818  ['monolithic', 'power', 'mpwr', 'beat', 'q2', ...                0
# 363819  ['michael', 'burry', 'strategic', 'emphasis', ...                0
#
#         Negative  Positive  Uncertainty
# 363810         1         1            0
# 363811         1         1            0
# 363812         1         1            0
# 363813         0         0            0
# 363814         1         1            0
# 363815         1         1            0
# 363816         1         1            0
# 363817         1         1            0
# 363818         1         1            0
# 363819         1         1            0

# %%
# group by ticker and sum the risk tags
df_risk_grouped = df_risk.groupby('ticker').sum()
df_risk_grouped = df_risk_grouped[['Negative', 'Positive', 'Uncertainty', 'Mixed Sentiment']]
df_risk_grouped
# Out:
#         Negative  Positive  Uncertainty  Mixed Sentiment
# ticker
# A            274       272            2                8
# AA           119       117            2                1
# AAL          495       493            2                1
# AAON          98        95            3                2
# AAP           98        97            1                2
# ...          ...       ...          ...              ...
# ZION          81        81            0                0
# ZM           296       296            0                5
# ZS           386       386           15               26
# ZTS          259       258            2               30
# ZWS           50        50            0                2
#
# [1363 rows x 4 columns]

# %%
# save df_risk and df_risk_grouped
df_risk.to_csv(f"{CSV_OUTPUT_PATH}/{HDBSCAN_RISK_TAGS}")
df_risk_grouped.to_csv(f"{CSV_OUTPUT_PATH}/{HDBSCAN_GROUPED_RISK_TAGS}")
